# %% [markdown]
# ### Breast Cancer DataSet
#
# * This dataset of breast cancer patients was obtained from the 2017 November update of the SEER Program of the NCI, which provides information on population-based cancer statistics.
#
# * The dataset involved female patients with infiltrating duct and lobular carcinoma breast cancer (SEER primary cites recode NOS histology codes 8522/3) diagnosed in 2006-2010.
#
# * Patients with unknown tumour size, examined regional LNs, positive regional LNs, and patients whose survival months were less than 1 month were excluded.
#
# * Thus, 4024 patients were ultimately included.

# %% [markdown]
# ### **Attributes Description**
#
# 1) `Age` - age of the patient
#
# 2) `Race` - race of the patient
# - Category: ['Other (American Indian/AK Native, Asian/Pacific Islander)','White', 'Black']
#
# 3) `Marital Status` - marital status
# - Category: ['Married (including common law)','Divorced','Single (never married)','Widowed','Separated']
#
# 4) `T Stage` - part of the TNM staging system, T stage refers to the size and extent of the primary tumor
# - Category: ['T2','T1','T3','T4']
#
# 5) `N Stage` - part of the TNM staging system, N stage refers to the involvement of nearby lymph nodes
# - Category: ['N3','N2','N1']
#
# 6) `6th Stage` - breast Adjusted American Joint Committee on Cancer (AJCC) 6th Stage
# - Category: ['IIIC','IIIA','IIB','IIA','IIIB']
# - Stage IIA: Any 1 of these conditions: There is no evidence of a tumor in the breast, but the cancer has spread to 1 to 3 axillary lymph nodes. It has not spread to distant parts of the body (T0, N1, M0). The tumor is 20 mm or smaller and has spread to 1 to 3 axillary lymph nodes (T1, N1, M0). The tumor is larger than 20 mm but not larger than 50 mm and has not spread to the axillary lymph nodes (T2, N0, M0).
# - Stage IIB: Either of these conditions: The tumor is larger than 20 mm but not larger than 50 mm and has spread to 1 to 3 axillary lymph nodes (T2, N1, M0). The tumor is larger than 50 mm but has not spread to the axillary lymph nodes (T3, N0, M0).
# - Stage IIIA: The tumor of any size has spread to 4 to 9 axillary lymph nodes or to internal mammary lymph nodes. It has not spread to other parts of the body (T0, T1, T2, or T3; N2; M0). Stage IIIA may also be a tumor larger than 50 mm that has spread to 1 to 3 axillary lymph nodes (T3, N1, M0).
# - Stage IIIB: The tumor has spread to the chest wall or caused swelling or ulceration of the breast, or it is diagnosed as inflammatory breast cancer. It may or may not have spread to up to 9 axillary or internal mammary lymph nodes. It has not spread to other parts of the body (T4; N0, N1, or N2; M0).
# - Stage IIIC: A tumor of any size that has spread to 10 or more axillary lymph nodes, the internal mammary lymph nodes, and/or the lymph nodes under the collarbone. It has not spread to other parts of the body (any T, N3, M0).
#
# 7) `differentiate` - the differentiation grade. It refers to how much cancer cells resemble normal, healthy cells in terms of their structure and function. The degree of differentiation is an important characteristic used by pathologists to classify and describe cancer cells.
# - Category: ['Moderately differentiated; Grade II','Poorly differentiated; Grade III', 'Well differentiated; Grade I','Undifferentiated; anaplastic; Grade IV']
# - Well-differentiated (Low Grade): Well-differentiated cancer cells closely resemble normal cells in both structure and function. These cells tend to grow and spread at a slower rate compared to less-differentiated cells. In terms of cancer prognosis, well-differentiated cancers often have a better outlook.
# - Moderately Differentiated (Intermediate Grade): Moderately differentiated cancer cells have some features of normal cells but also exhibit some abnormal characteristics. The degree of abnormality falls between well-differentiated and poorly differentiated cells.
# - Poorly Differentiated (High Grade): Poorly differentiated cancer cells bear little resemblance to normal cells. They tend to grow and divide rapidly, and their appearance may be quite different from the tissue of origin. Poorly differentiated cancers are often associated with a more aggressive behavior and poorer prognosis.
#
# 8) `Grade` - the grade for differentiation
# - Category: ['3', '2', '1', ' anaplastic; Grade IV']
#
# 9) `A Stage` -
# - Category: ['Regional','Distant']
# - Regional — A neoplasm that has extended
# - Distant — A neoplasm that has spread to parts of the body remote from
#
# 10) `Tumor Size` - indicates exact size in millimeters
#
# 11) `Estrogen Status` - estrogen status
# - Category: ['Positive','Negative']
#
# 12) `Progesterone Status` - progestrone status
# - Category: ['Positive','Negative']
#
# 13) `Regional Node Examined` - refers to the number of regional lymph nodes that were examined during the diagnostic process.
#
# 14) `Regional Node Positive` - refers to the presence of cancer cells in the regional lymph nodes.
#
# 15) `Survival Months` - number of survival months
#
# 16) `Status` - status of the patient
# - Category: ['Alive','Dead']

# %% [raw]
# num_feats = ['Age','Tumor Size','Regional Node Examined','Regional Node Positive','Survival Months']
# nominal_feats = ['Race','Marital Status']
# ordinal_feats = ['T Stage','N Stage','6th Stage','differentiate']
# binary_feats = ['A Stage','Estrogen Status','Progesterone Status']
# target_feats = ['Status']

# %% [markdown]
# Dataset Link: https://www.kaggle.com/datasets/reihanenamdari/breast-cancer

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline
import warnings
warnings.filterwarnings("ignore")

# %% [markdown]
# ## Verisetinin Incelenmesi

# %%
df = pd.read_csv('Breast_Cancer.csv')
data = df.copy()

# %%
df.head(n=5)
# Out:
#    Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 0   68  White        Married       T1      N1       IIA
# 1   50  White        Married       T2      N2      IIIA
# 2   58  White       Divorced       T3      N3      IIIC
# 3   58  White        Married       T1      N1       IIA
# 4   47  White        Married       T2      N1       IIB
#
#                differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 0      Poorly differentiated     3  Regional           4        Positive
# 1  Moderately differentiated     2  Regional          35        Positive
# 2  Moderately differentiated     2  Regional          63        Positive
# 3      Poorly differentiated     3  Regional          18        Positive
# 4      Poorly differentiated     3  Regional          41        Positive
#
#   Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 0            Positive                      24                      1
# ...

# %%
df.tail(n=5)
# Out:
#       Age   Race Marital Status T Stage  N Stage 6th Stage  \
# 4019   62  Other        Married       T1      N1       IIA
# 4020   56  White       Divorced       T2      N2      IIIA
# 4021   68  White        Married       T2      N1       IIB
# 4022   58  Black       Divorced       T2      N1       IIB
# 4023   46  White        Married       T2      N1       IIB
#
#                   differentiate Grade   A Stage  Tumor Size Estrogen Status  \
# 4019  Moderately differentiated     2  Regional           9        Positive
# 4020  Moderately differentiated     2  Regional          46        Positive
# 4021  Moderately differentiated     2  Regional          22        Positive
# 4022  Moderately differentiated     2  Regional          44        Positive
# 4023  Moderately differentiated     2  Regional          30        Positive
#
#      Progesterone Status  Regional Node Examined  Reginol Node Positive  \
# 4019            Positive                       1                      1
# ...

# %%
#Verisetinin sekli (satir, sutun sayısı)
df.shape
# Out:
# (4024, 16)

# %%
#Verisetindeki gozlem (n) sayisi
len(df.index)
# Out:
# 4024

# %%
#Verisetindeki ozellikler (feature)
df.columns
# Out:
# Index(['Age', 'Race', 'Marital Status', 'T Stage ', 'N Stage', '6th Stage',
#        'differentiate', 'Grade', 'A Stage', 'Tumor Size', 'Estrogen Status',
#        'Progesterone Status', 'Regional Node Examined',
#        'Reginol Node Positive', 'Survival Months', 'Status'],
#       dtype='object')

# %%
#Verisetindeki ozellik (feature) sayisi

len(df.columns)
# Out:
# 16

# %%
#Veri setindeki numerik sutunları bulma
num_df = df.select_dtypes(include='int64')

# %%
#Veri setindeki kategorik sutunları bulma
kat_df = df.select_dtypes(include='object')

# %%
# kac adet numerik sutun var
len(num_df.columns)
# Out:
# 5

# %%
# kac adet kategorik sutun var
len(kat_df.columns)
# Out:
# 11

# %% [markdown]
# Dolayısı ile veriseti içinde:
# * Toplam 16 sütun var
# * Bunlardan 15'i girdi (input) sutunları, 1'i cikti (y) sutunu
# * Sutunlarının 5'i sayisal sutun, 11'i kategorik

# %%
# Eksik verilere (Missing Value) bakma
df.isnull().sum()
# Out:
# Age                       0
# Race                      0
# Marital Status            0
# T Stage                   0
# N Stage                   0
# 6th Stage                 0
# differentiate             0
# Grade                     0
# A Stage                   0
# Tumor Size                0
# Estrogen Status           0
# Progesterone Status       0
# Regional Node Examined    0
# Reginol Node Positive     0
# Survival Months           0
# Status                    0
# dtype: int64

# %%
# her sütun icindeki tekil (unique) veri adedini bakma

for col in df.columns:
    print(col, df[col].nunique())
# Out:
# Age 40
# Race 3
# Marital Status 5
# T Stage  4
# N Stage 3
# 6th Stage 5
# differentiate 4
# Grade 4
# A Stage 2
# Tumor Size 110
# Estrogen Status 2
# Progesterone Status 2
# Regional Node Examined 54
# Reginol Node Positive 38
# Survival Months 107
# Status 2

# %%
for col in df.columns:
    values = []
    
    # numerik olmayanlar -> kategorik
    if col not in df.describe().columns:
        for val in df[col].unique():
            values.append(val)
        
        print("{0} -> {1}".format(col, values))
# Out:
# Race -> ['White', 'Black', 'Other']
# Marital Status -> ['Married', 'Divorced', 'Single ', 'Widowed', 'Separated']
# T Stage  -> ['T1', 'T2', 'T3', 'T4']
# N Stage -> ['N1', 'N2', 'N3']
# 6th Stage -> ['IIA', 'IIIA', 'IIIC', 'IIB', 'IIIB']
# differentiate -> ['Poorly differentiated', 'Moderately differentiated', 'Well differentiated', 'Undifferentiated']
# Grade -> ['3', '2', '1', ' anaplastic; Grade IV']
# A Stage -> ['Regional', 'Distant']
# Estrogen Status -> ['Positive', 'Negative']
# Progesterone Status -> ['Positive', 'Negative']
# Status -> ['Alive', 'Dead']

# %%
#Sutun isimlerinin duzenlenmesi
df.columns = ['age', 'race', 'marital_status', 't_stage', 'n_stage', '6th_stage',
       'differentiate', 'grade', 'a_stage', 'tumor_size', 'estrogen_status',
       'progesterone_status', 'regional_node_examined',
       'regional_node_positive', 'survival_months', 'status']

# %%
#Genel Bilgiler
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 4024 entries, 0 to 4023
# Data columns (total 16 columns):
#  #   Column                  Non-Null Count  Dtype
# ---  ------                  --------------  -----
#  0   age                     4024 non-null   int64
#  1   race                    4024 non-null   object
#  2   marital_status          4024 non-null   object
#  3   t_stage                 4024 non-null   object
#  4   n_stage                 4024 non-null   object
#  5   6th_stage               4024 non-null   object
#  6   differentiate           4024 non-null   object
#  7   grade                   4024 non-null   object
#  8   a_stage                 4024 non-null   object
#  9   tumor_size              4024 non-null   int64
#  10  estrogen_status         4024 non-null   object
#  11  progesterone_status     4024 non-null   object
#  12  regional_node_examined  4024 non-null   int64
#  13  regional_node_positive  4024 non-null   int64
# ...

# %% [markdown]
# Race, Marital Status, T Stage, N Stage, 6th Stage, Grade, A Stage, Estrogen Status, Progesterone Status, and Status are categorical attributes.
#
# Age, Tumor Size, Regional Node Examined, Reginol Node Positive, and Survival Months are numerical attributes.

# %%
#Temel Istatistikler
df.describe().T
# Out:
#                          count       mean        std   min   25%   50%   75%  \
# age                     4024.0  53.972167   8.963134  30.0  47.0  54.0  61.0
# tumor_size              4024.0  30.473658  21.119696   1.0  16.0  25.0  38.0
# regional_node_examined  4024.0  14.357107   8.099675   1.0   9.0  14.0  19.0
# regional_node_positive  4024.0   4.158052   5.109331   1.0   1.0   2.0   5.0
# survival_months         4024.0  71.297962  22.921430   1.0  56.0  73.0  90.0
#
#                           max
# age                      69.0
# tumor_size              140.0
# regional_node_examined   61.0
# regional_node_positive   46.0
# survival_months         107.0

# %% [markdown]
# For the attributes age and survival months mean is less than median. The data is skewed to the left. The distribution is negatively skewed.
#
# For the attributes tumor size, regional node examined, and reginol nodel positive the mean is greater than the median. The data is skewed to the right. The distribution is positively skewed.

# %%
## differentiate ve grade sutunları aynı verileri temsil etmektedir. Bu nedenle grade sutunu silinir.
df.drop('grade', axis=1, inplace=True)

# %%
df.head(n=5)
# Out:
#    age   race marital_status t_stage n_stage 6th_stage  \
# 0   68  White        Married      T1      N1       IIA
# 1   50  White        Married      T2      N2      IIIA
# 2   58  White       Divorced      T3      N3      IIIC
# 3   58  White        Married      T1      N1       IIA
# 4   47  White        Married      T2      N1       IIB
#
#                differentiate   a_stage  tumor_size estrogen_status  \
# 0      Poorly differentiated  Regional           4        Positive
# 1  Moderately differentiated  Regional          35        Positive
# 2  Moderately differentiated  Regional          63        Positive
# 3      Poorly differentiated  Regional          18        Positive
# 4      Poorly differentiated  Regional          41        Positive
#
#   progesterone_status  regional_node_examined  regional_node_positive  \
# 0            Positive                      24                       1
# 1            Positive                      14                       5
# ...

# %% [markdown]
# ### Kesifsel Veri Analizi (Explatory Data Analysis) (EDA)

# %%
sns.countplot(x=df['status'])
plt.title('Patient Status')
plt.show()

# %%
sns.countplot(x=df['progesterone_status'])
plt.title('Progesterone Status')
plt.show()

# %%
sns.countplot(x=df['estrogen_status'])
plt.title('Estrogen Status')
plt.show()

# %%
sns.countplot(x=df['differentiate'])
plt.title('Differentiate')
plt.xticks(rotation=30)
plt.show()

# %%
sns.countplot(x=df['6th_stage']),
plt.title('6th Stage')
plt.show()

# %%
sns.countplot(x=df['a_stage'])
plt.title('A Stage')
plt.show()

# %%
sns.countplot(x=df['n_stage'])
plt.title('N Stage')
plt.show()

# %%
sns.countplot(x=df['t_stage'])
plt.title('T Stage')
plt.show()

# %%
sns.countplot(x=df['marital_status'])
plt.title('Marital Status')
plt.show()

# %%
sns.countplot(x=df['race'])
plt.title('Race of Patient')
plt.show()

# %%
sns.histplot(data=df, x="age", kde=True,hue='status',stat='count',multiple='stack')
plt.title('Age - Number of People')
plt.show()

# %%
sns.histplot(data=df, x="tumor_size", kde=True,hue='status',stat='count',multiple='stack')
plt.title('Tumor Size - Number of People')
plt.show()

# %%
sns.histplot(data=df, x="regional_node_examined", kde=True,hue='status',stat='count',multiple='stack')
plt.title('Regional Node Examined - Number of People')
plt.show()

# %%
sns.histplot(data=df, x="regional_node_positive", kde=True,hue='status',stat='count',multiple='stack')
plt.title('Regional Node Positive - Number of People')
plt.show()

# %%
sns.histplot(data=df, x="survival_months", kde=True,hue='status',stat='count',multiple='stack')
plt.title('Survival Months - Number of People')
plt.show()

# %%
sns.heatmap(df.corr(),annot=True,linewidths=1.5,cmap='crest')
plt.show()

# %%
sns.pairplot(df)
plt.show()

# %%
sns.countplot(data=df, x="differentiate", hue="status")
plt.title('Differentiate')
plt.xticks(rotation=30)
plt.show()

# %%
sns.countplot(data=df, x="estrogen_status", hue="status")
plt.title('Estrogen Status')
plt.show()

# %%
sns.countplot(data=df, x="progesterone_status", hue="status")
plt.title('Progesterone Status')
plt.show()

# %%
sns.catplot(data=df,x='race',y='tumor_size',hue='differentiate',kind='bar',col='status',ci=None)
plt.show()

# %% [markdown]
# ### Veri On isleme (Data Preprocessing)

# %% [markdown]
# ### Kategorik Verilerin Donusturulmesi (Encoding)

# %% [raw]
# Note that there are categorical column Grade, 6th Stage, T Stage, N Stage, which are ordinal. All other categorical columns are nominal.
#
# Let's first encode Grade. The higher the tumor grade is, the more aggressive the tumor cells are. This indicates that there is a natural ordering among tumor grades. It is an ordinal problem. There is an inherent order among the possible values in this column (Grade I < Grade II < Grade III. Thus, we can encode it by replacing 'Grade 1' by 1, 'Grade 2' by 2, etc.

# %%
df['differentiate']=df['differentiate'].map({'Well differentiated' : 0,
                                             'Moderately differentiated': 1,
                                             'Poorly differentiated': 2,
                                             'Undifferentiated' : 3})
df.head()
# Out:
#    age   race marital_status t_stage n_stage 6th_stage  differentiate  \
# 0   68  White        Married      T1      N1       IIA              2
# 1   50  White        Married      T2      N2      IIIA              1
# 2   58  White       Divorced      T3      N3      IIIC              1
# 3   58  White        Married      T1      N1       IIA              2
# 4   47  White        Married      T2      N1       IIB              2
#
#     a_stage  tumor_size estrogen_status progesterone_status  \
# 0  Regional           4        Positive            Positive
# 1  Regional          35        Positive            Positive
# 2  Regional          63        Positive            Positive
# 3  Regional          18        Positive            Positive
# 4  Regional          41        Positive            Positive
#
#    regional_node_examined  regional_node_positive  survival_months status
# 0                      24                       1               60  Alive
# ...

# %%
df['6th_stage']=df['6th_stage'].map({'IIA': 0, 'IIB': 1, 'IIIA': 2, 'IIIB': 3, 'IIIC': 4})
df.head()
# Out:
#    age   race marital_status t_stage n_stage  6th_stage  differentiate  \
# 0   68  White        Married      T1      N1          0              2
# 1   50  White        Married      T2      N2          2              1
# 2   58  White       Divorced      T3      N3          4              1
# 3   58  White        Married      T1      N1          0              2
# 4   47  White        Married      T2      N1          1              2
#
#     a_stage  tumor_size estrogen_status progesterone_status  \
# 0  Regional           4        Positive            Positive
# 1  Regional          35        Positive            Positive
# 2  Regional          63        Positive            Positive
# 3  Regional          18        Positive            Positive
# 4  Regional          41        Positive            Positive
#
#    regional_node_examined  regional_node_positive  survival_months status
# 0                      24                       1               60  Alive
# ...

# %%
df['n_stage']=df['n_stage'].map({'N1': 0, 'N2': 1, 'N3': 2})
df.head()
# Out:
#    age   race marital_status t_stage  n_stage  6th_stage  differentiate  \
# 0   68  White        Married      T1        0          0              2
# 1   50  White        Married      T2        1          2              1
# 2   58  White       Divorced      T3        2          4              1
# 3   58  White        Married      T1        0          0              2
# 4   47  White        Married      T2        0          1              2
#
#     a_stage  tumor_size estrogen_status progesterone_status  \
# 0  Regional           4        Positive            Positive
# 1  Regional          35        Positive            Positive
# 2  Regional          63        Positive            Positive
# 3  Regional          18        Positive            Positive
# 4  Regional          41        Positive            Positive
#
#    regional_node_examined  regional_node_positive  survival_months status
# 0                      24                       1               60  Alive
# ...

# %%
df['t_stage']=df['t_stage'].map({'T1': 0, 'T2': 1, 'T3': 2, 'T4':3})
df.tail()
# Out:
#       age   race marital_status  t_stage  n_stage  6th_stage  differentiate  \
# 4019   62  Other        Married        0        0          0              1
# 4020   56  White       Divorced        1        1          2              1
# 4021   68  White        Married        1        0          1              1
# 4022   58  Black       Divorced        1        0          1              1
# 4023   46  White        Married        1        0          1              1
#
#        a_stage  tumor_size estrogen_status progesterone_status  \
# 4019  Regional           9        Positive            Positive
# 4020  Regional          46        Positive            Positive
# 4021  Regional          22        Positive            Negative
# 4022  Regional          44        Positive            Positive
# 4023  Regional          30        Positive            Positive
#
#       regional_node_examined  regional_node_positive  survival_months status
# ...

# %%
df['status']=df['status'].map({'Alive': 1, 'Dead': 0})
df.head()
# Out:
#    age   race marital_status  t_stage  n_stage  6th_stage  differentiate  \
# 0   68  White        Married        0        0          0              2
# 1   50  White        Married        1        1          2              1
# 2   58  White       Divorced        2        2          4              1
# 3   58  White        Married        0        0          0              2
# 4   47  White        Married        1        0          1              2
#
#     a_stage  tumor_size estrogen_status progesterone_status  \
# 0  Regional           4        Positive            Positive
# 1  Regional          35        Positive            Positive
# 2  Regional          63        Positive            Positive
# 3  Regional          18        Positive            Positive
# 4  Regional          41        Positive            Positive
#
#    regional_node_examined  regional_node_positive  survival_months  status
# 0                      24                       1               60       1
# ...

# %%
nominal = ['race','marital_status','a_stage','estrogen_status','progesterone_status']
df = pd.get_dummies(df, columns=nominal,drop_first=True)
df.head()
# Out:
#    age  t_stage  n_stage  6th_stage  differentiate  tumor_size  \
# 0   68        0        0          0              2           4
# 1   50        1        1          2              1          35
# 2   58        2        2          4              1          63
# 3   58        0        0          0              2          18
# 4   47        1        0          1              2          41
#
#    regional_node_examined  regional_node_positive  survival_months  status  \
# 0                      24                       1               60       1
# 1                      14                       5               62       1
# 2                      14                       7               75       1
# 3                       2                       1               84       1
# 4                       3                       1               50       1
#
#    race_Other  race_White  marital_status_Married  marital_status_Separated  \
# ...

# %% [markdown]
# ###  Bagimsiz Degiskenler ve Bagimli Degisken (Feature Vector and Target Variable)

# %%
X = df.drop(['status'], axis=1)
y = df['status'] # Bagimli Degisken

# %%
X.shape
# Out:
# (4024, 18)

# %%
y.shape
# Out:
# (4024,)

# %% [markdown]
# ## Train-Test Split

# %%
from sklearn.model_selection import train_test_split

X_train, X_test, y_train, y_test = train_test_split(X, y, test_size = 0.2, random_state = 0)

# %%
# X_train ve X_test sekilleri

X_train.shape, X_test.shape
# Out:
# ((3219, 18), (805, 18))

# %% [markdown]
# ### Olceklendirme (Feature Scaling)

# %%
# X_train sutunlarının bir degiskende tutulmasi
cols = X_train.columns

# %%
#Standard Scaler kullanılmasi
from sklearn.preprocessing import StandardScaler

scaler = StandardScaler()

# X_train uzerinde fit ve transform yapilmasi
X_train = scaler.fit_transform(X_train)

# X_test'i transform yapilmasi
X_test = scaler.transform(X_test)

# %%
# StandardScaler transform sonrası veri yapilari degisir
type(X_train)
# Out:
# numpy.ndarray

# %%
# geri pandas.DataFrame'e cevirmemiz gerelir
X_train = pd.DataFrame(X_train, columns=[cols])
X_test = pd.DataFrame(X_test, columns=[cols])

# %%
# veriler (olceklendirilmis halde)
X_train[cols]
# Out:
#            age   t_stage   n_stage 6th_stage differentiate tumor_size  \
# 0    -0.224718 -1.030297  0.802468  0.530613      1.319207  -0.497418
# 1     0.111471 -1.030297  0.802468  0.530613     -0.240296  -0.591647
# 2    -0.560906 -1.030297  0.802468  0.530613      1.319207  -0.921448
# 3    -0.672969 -1.030297 -0.635008 -1.046528     -1.799800  -0.874334
# 4    -0.112655  0.277997 -0.635008 -0.257957     -1.799800  -0.261845
# ...        ...       ...       ...       ...           ...        ...
# 3214  1.120037  0.277997 -0.635008 -0.257957     -0.240296  -0.026272
# 3215 -0.112655  0.277997 -0.635008 -0.257957     -1.799800   0.444873
# 3216 -1.009158  0.277997 -0.635008 -0.257957     -0.240296  -0.403189
# 3217 -1.457409  0.277997  0.802468  0.530613      1.319207  -0.120501
# 3218 -0.672969  0.277997 -0.635008 -0.257957     -0.240296  -0.356074
#
#      regional_node_examined regional_node_positive survival_months race_Other  \
# ...

# %% [markdown]
# ### Logistic Regression

# %%
from sklearn.linear_model import LogisticRegression
logreg = LogisticRegression()
logreg.fit(X_train, y_train)
y_pred = logreg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix
logreg_cm = confusion_matrix(y_test, y_pred)

print('Logistic Regression Confusion matrix\n\n', logreg_cm)
# Out:
# Logistic Regression Confusion matrix
#
#  [[ 51  73]
#  [ 12 669]]

# %%
from sklearn.metrics import accuracy_score
print('Logistic Regression Accuracy : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))

from sklearn.metrics import precision_score
print('Logistic Regression Precision : {0:0.4f}'.format(precision_score(y_test,y_pred)))

from sklearn.metrics import recall_score
print('Logistic Regression Recall : {0:0.4f}'.format(recall_score(y_test,y_pred)))

from sklearn.metrics import f1_score
print('Logistic Regression F1 Score : {0:0.4f}'.format(f1_score(y_test,y_pred)))
# Out:
# Logistic Regression Accuracy : 0.8944
# Logistic Regression Precision : 0.9016
# Logistic Regression Recall : 0.9824
# Logistic Regression F1 Score : 0.9403

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.41      0.55       124
#            1       0.90      0.98      0.94       681
#
#     accuracy                           0.89       805
#    macro avg       0.86      0.70      0.74       805
# weighted avg       0.89      0.89      0.88       805

# %%
from sklearn.metrics import roc_auc_score
auc_logreg = roc_auc_score(y_test,y_pred)
print('AUC Logistic Regression:%.3f'% auc_logreg)
# Out:
# AUC Logistic Regression:0.697

# %%
from sklearn.metrics import roc_curve

fpr_logreg, tpr_logreg, thresholds_logreg = roc_curve(y_test,y_pred)

# %% [markdown]
# ### K-Nearest Neighbors (KNN)

# %%
from sklearn.neighbors import KNeighborsClassifier

knn = KNeighborsClassifier(n_neighbors=3, metric='minkowski')
knn.fit(X_train,y_train)
y_pred = knn.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

knn_cm = confusion_matrix(y_test,y_pred)
print('K-Nearest Neighbors Confusion matrix\n\n', knn_cm)
# Out:
# K-Nearest Neighbors Confusion matrix
#
#  [[ 50  74]
#  [ 28 653]]

# %%
from sklearn.metrics import accuracy_score
print('K-Nearest Neighbors Accuracy : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))

from sklearn.metrics import precision_score
print('K-Nearest Neighbors Precision : {0:0.4f}'.format(precision_score(y_test,y_pred)))

from sklearn.metrics import recall_score
print('K-Nearest Neighbors Recall : {0:0.4f}'.format(recall_score(y_test,y_pred)))

from sklearn.metrics import f1_score
print('K-Nearest Neighbors F1 Score : {0:0.4f}'.format(f1_score(y_test,y_pred)))
# Out:
# K-Nearest Neighbors Accuracy : 0.8733
# K-Nearest Neighbors Precision : 0.8982
# K-Nearest Neighbors Recall : 0.9589
# K-Nearest Neighbors F1 Score : 0.9276

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.64      0.40      0.50       124
#            1       0.90      0.96      0.93       681
#
#     accuracy                           0.87       805
#    macro avg       0.77      0.68      0.71       805
# weighted avg       0.86      0.87      0.86       805

# %%
from sklearn.metrics import roc_auc_score
auc_knn = roc_auc_score(y_test,y_pred)
print('AUC SVM:%.3f'% auc_knn)
# Out:
# AUC SVM:0.681

# %%
from sklearn.metrics import roc_curve

fpr_knn, tpr_knn, thresholds_knn = roc_curve(y_test,y_pred)

# %% [markdown]
# ### Support Vector Machine (SVM)

# %%
from sklearn.svm import SVC
SVM_classifier = SVC(kernel = 'rbf')
SVM_classifier.fit(X_train,y_train)
y_pred = SVM_classifier.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

SVM_cm = confusion_matrix(y_test, y_pred)
print('SVM Confusion matrix\n\n',SVM_cm)
# Out:
# SVM Confusion matrix
#
#  [[ 40  84]
#  [  7 674]]

# %%
from sklearn.metrics import accuracy_score
print('SVM Accuracy : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))

from sklearn.metrics import precision_score
print('SVM Precision : {0:0.4f}'.format(precision_score(y_test,y_pred)))

from sklearn.metrics import recall_score
print('SVM Recall : {0:0.4f}'.format(recall_score(y_test,y_pred)))

from sklearn.metrics import f1_score
print('SVM F1 Score : {0:0.4f}'.format(f1_score(y_test,y_pred)))
# Out:
# SVM Accuracy : 0.8870
# SVM Precision : 0.8892
# SVM Recall : 0.9897
# SVM F1 Score : 0.9368

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.85      0.32      0.47       124
#            1       0.89      0.99      0.94       681
#
#     accuracy                           0.89       805
#    macro avg       0.87      0.66      0.70       805
# weighted avg       0.88      0.89      0.86       805

# %%
from sklearn.metrics import roc_auc_score
auc_SVM = roc_auc_score(y_test,y_pred)
print('AUC SVM:%.3f'% auc_SVM)
# Out:
# AUC SVM:0.656

# %%
from sklearn.metrics import roc_curve

fpr_SVM, tpr_SVM, thresholds_SVM = roc_curve(y_test,y_pred)

# %% [markdown]
# ### Decision Tree

# %%
from sklearn.tree import DecisionTreeRegressor
dt_reg = DecisionTreeRegressor()
dt_reg.fit(X_train,y_train)
y_pred = dt_reg.predict(X_test)

# %%
from sklearn.metrics import confusion_matrix

dt_cm = confusion_matrix(y_test, y_pred)
print('Decision Tree Confusion matrix\n\n',dt_cm)
# Out:
# Decision Tree Confusion matrix
#
#  [[ 63  61]
#  [ 79 602]]

# %%
from sklearn.metrics import accuracy_score
print('Decision Tree Accuracy : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))

from sklearn.metrics import precision_score
print('Decision Tree Precision : {0:0.4f}'.format(precision_score(y_test,y_pred)))

from sklearn.metrics import recall_score
print('Decision Tree Recall : {0:0.4f}'.format(recall_score(y_test,y_pred)))

from sklearn.metrics import f1_score
print('Decision Tree F1 Score : {0:0.4f}'.format(f1_score(y_test,y_pred)))
# Out:
# Decision Tree Accuracy : 0.8261
# Decision Tree Precision : 0.9080
# Decision Tree Recall : 0.8840
# Decision Tree F1 Score : 0.8958

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.44      0.51      0.47       124
#            1       0.91      0.88      0.90       681
#
#     accuracy                           0.83       805
#    macro avg       0.68      0.70      0.68       805
# weighted avg       0.84      0.83      0.83       805

# %%
from sklearn.metrics import roc_auc_score
auc_dt = roc_auc_score(y_test,y_pred)
print('AUC Decision Tree:%.3f'% auc_dt)
# Out:
# AUC Decision Tree:0.696

# %%
from sklearn.metrics import roc_curve

fpr_dt, tpr_dt, thresholds_dt = roc_curve(y_test,y_pred)

# %% [markdown]
# ### Random Forest

# %%
from sklearn.ensemble import RandomForestClassifier
rfc = RandomForestClassifier(n_estimators=100, random_state=0)
rfc.fit(X_train, y_train)
y_pred = rfc.predict(X_test)

# %%
rf_cm = confusion_matrix(y_test, y_pred)

print('Random Forest Confusion matrix\n\n', rf_cm)
# Out:
# Random Forest Confusion matrix
#
#  [[ 57  67]
#  [ 13 668]]

# %%
from sklearn.metrics import accuracy_score
print('Random Forest Accuracy : {0:0.4f}'. format(accuracy_score(y_test, y_pred)))

from sklearn.metrics import precision_score
print('Random Forest Precision : {0:0.4f}'.format(precision_score(y_test,y_pred)))

from sklearn.metrics import recall_score
print('Random Forest Recall : {0:0.4f}'.format(recall_score(y_test,y_pred)))

from sklearn.metrics import f1_score
print('Random Forest F1 Score : {0:0.4f}'.format(f1_score(y_test,y_pred)))
# Out:
# Random Forest Accuracy : 0.9006
# Random Forest Precision : 0.9088
# Random Forest Recall : 0.9809
# Random Forest F1 Score : 0.9435

# %%
from sklearn.metrics import classification_report

print(classification_report(y_test, y_pred))
# Out:
#               precision    recall  f1-score   support
#
#            0       0.81      0.46      0.59       124
#            1       0.91      0.98      0.94       681
#
#     accuracy                           0.90       805
#    macro avg       0.86      0.72      0.77       805
# weighted avg       0.89      0.90      0.89       805

# %%
from sklearn.metrics import roc_auc_score
auc_rf = roc_auc_score(y_test,y_pred)
print('AUC Random Forest:%.3f'% auc_rf)
# Out:
# AUC Random Forest:0.720

# %%
from sklearn.metrics import roc_curve

fpr_rf, tpr_rf, thresholds_rf = roc_curve(y_test,y_pred)

# %%
plt.style.use('ggplot')
plt.plot(fpr_logreg, tpr_logreg,label = 'Logistic Regression')
plt.plot(fpr_knn, tpr_knn,label = 'KNN')
plt.plot(fpr_SVM, tpr_SVM,label = 'SVM')
plt.plot(fpr_dt, tpr_dt,label = 'Decision Tree')
plt.plot(fpr_rf, tpr_rf,label = 'Random Forest')

plt.plot([0,1],[0,1],label='random')
plt.plot([0,0,1,1],[0,1,1,1],label='perfect')
plt.legend()
plt.xlabel('False Positive Rate')
plt.ylabel('True Positive Rate')
plt.show()
